# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from docplex.mp.model import  Model

# %% [markdown]
# ![alternatvie text](pics/2023-07-07-09-59-58.png)

# %%
arcs = {(9,0):7 , (9,1):2 , (9,2):1 ,
       (0,3):2, (0,4):4,
       (1,4):5, (1,5):6, 
       (2,3):4, (2,7):8,
       (3,6):7, (3,7):1,
       (4,6):3, (4,5):8, (4,8):3,
       (5,8):3, 
       (6,10):1,
       (7,10):3,
       (8,10):4
       }

# %%
all = []
for i in arcs:
    all.append([i[0],i[1],arcs[i]])
Network = pd.DataFrame(all, columns = ['origin','destination','capacity'])
Network
# Out:
#     origin  destination  capacity
# 0        9            0         7
# 1        9            1         2
# 2        9            2         1
# 3        0            3         2
# 4        0            4         4
# 5        1            4         5
# 6        1            5         6
# 7        2            3         4
# 8        2            7         8
# 9        3            6         7
# 10       3            7         1
# 11       4            6         3
# 12       4            5         8
# 13       4            8         3
# 14       5            8         3
# 15       6           10         1
# 16       7           10         3
# 17       8           10         4

# %%
mdl = Model(name="NetworkFlow")
Network['flow'] = 0

for row in Network.itertuples():
    dv = mdl.continuous_var(lb=0, ub=row.capacity, name='flow_%s_%s' %(row.origin, row.destination))
    Network['flow'].loc[row.Index]= dv

Network
# Out:
#     origin  destination  capacity       flow
# 0        9            0         7   flow_9_0
# 1        9            1         2   flow_9_1
# 2        9            2         1   flow_9_2
# 3        0            3         2   flow_0_3
# 4        0            4         4   flow_0_4
# 5        1            4         5   flow_1_4
# 6        1            5         6   flow_1_5
# 7        2            3         4   flow_2_3
# 8        2            7         8   flow_2_7
# 9        3            6         7   flow_3_6
# 10       3            7         1   flow_3_7
# 11       4            6         3   flow_4_6
# 12       4            5         8   flow_4_5
# 13       4            8         3   flow_4_8
# 14       5            8         3   flow_5_8
# 15       6           10         1  flow_6_10
# 16       7           10         3  flow_7_10
# 17       8           10         4  flow_8_10

# %%
S = mdl.continuous_var(lb=0, ub=100, name = 'Source')

# %%
Outgoing_Flow = Network[['origin','flow']].groupby('origin').agg(sum).reset_index().rename(columns = {'flow':"outgoing_flow"})
Outgoing_Flow
# Out:
#    origin               outgoing_flow
# 0       0           flow_0_3+flow_0_4
# 1       1           flow_1_4+flow_1_5
# 2       2           flow_2_3+flow_2_7
# 3       3           flow_3_6+flow_3_7
# 4       4  flow_4_6+flow_4_5+flow_4_8
# 5       5                    flow_5_8
# 6       6                   flow_6_10
# 7       7                   flow_7_10
# 8       8                   flow_8_10
# 9       9  flow_9_0+flow_9_1+flow_9_2

# %%
Incoming_Flow = Network[['destination','flow']].groupby('destination').agg(sum).reset_index().rename(columns = {'flow':"incoming_Flow"})
Incoming_Flow
# Out:
#    destination                  incoming_Flow
# 0            0                       flow_9_0
# 1            1                       flow_9_1
# 2            2                       flow_9_2
# 3            3              flow_0_3+flow_2_3
# 4            4              flow_0_4+flow_1_4
# 5            5              flow_1_5+flow_4_5
# 6            6              flow_3_6+flow_4_6
# 7            7              flow_2_7+flow_3_7
# 8            8              flow_4_8+flow_5_8
# 9           10  flow_6_10+flow_7_10+flow_8_10

# %%
Inflow_Outflow = pd.merge(Incoming_Flow, Outgoing_Flow, left_on='destination', right_on = 'origin', how = 'outer')
Inflow_Outflow
# Out:
#     destination                  incoming_Flow  origin
# 0           0.0                       flow_9_0     0.0  \
# 1           1.0                       flow_9_1     1.0
# 2           2.0                       flow_9_2     2.0
# 3           3.0              flow_0_3+flow_2_3     3.0
# 4           4.0              flow_0_4+flow_1_4     4.0
# 5           5.0              flow_1_5+flow_4_5     5.0
# 6           6.0              flow_3_6+flow_4_6     6.0
# 7           7.0              flow_2_7+flow_3_7     7.0
# 8           8.0              flow_4_8+flow_5_8     8.0
# 9          10.0  flow_6_10+flow_7_10+flow_8_10     NaN
# 10          NaN                            NaN     9.0
#
#                  outgoing_flow
# 0            flow_0_3+flow_0_4
# 1            flow_1_4+flow_1_5
# 2            flow_2_3+flow_2_7
# 3            flow_3_6+flow_3_7
# 4   flow_4_6+flow_4_5+flow_4_8
# 5                     flow_5_8
# 6                    flow_6_10
# 7                    flow_7_10
# 8                    flow_8_10
# 9                          NaN
# 10  flow_9_0+flow_9_1+flow_9_2

# %%
Inflow_Outflow.loc[Inflow_Outflow['origin']==9,'incoming_Flow']=S

Inflow_Outflow.loc[Inflow_Outflow['destination']==10,'outgoing_flow']=S

# %%
Inflow_Outflow
# Out:
#     destination                  incoming_Flow  origin
# 0           0.0                       flow_9_0     0.0  \
# 1           1.0                       flow_9_1     1.0
# 2           2.0                       flow_9_2     2.0
# 3           3.0              flow_0_3+flow_2_3     3.0
# 4           4.0              flow_0_4+flow_1_4     4.0
# 5           5.0              flow_1_5+flow_4_5     5.0
# 6           6.0              flow_3_6+flow_4_6     6.0
# 7           7.0              flow_2_7+flow_3_7     7.0
# 8           8.0              flow_4_8+flow_5_8     8.0
# 9          10.0  flow_6_10+flow_7_10+flow_8_10     NaN
# 10          NaN                         Source     9.0
#
#                  outgoing_flow
# 0            flow_0_3+flow_0_4
# 1            flow_1_4+flow_1_5
# 2            flow_2_3+flow_2_7
# 3            flow_3_6+flow_3_7
# 4   flow_4_6+flow_4_5+flow_4_8
# 5                     flow_5_8
# 6                    flow_6_10
# 7                    flow_7_10
# 8                    flow_8_10
# 9                       Source
# 10  flow_9_0+flow_9_1+flow_9_2

# %%
for row in Inflow_Outflow.itertuples():
    mdl.add( row.incoming_Flow == row.outgoing_flow )

# %%
mdl.maximize ( S )
msol = mdl.solve()
msol.display()
# Out:
# solution for: NetworkFlow
# objective: 7.000
# status: OPTIMAL_SOLUTION(2)
# flow_9_0 = 6.000
# flow_9_2 = 1.000
# flow_0_3 = 2.000
# flow_0_4 = 4.000
# flow_2_7 = 1.000
# flow_3_6 = 1.000
# flow_3_7 = 1.000
# flow_4_5 = 3.000
# flow_4_8 = 1.000
# flow_5_8 = 3.000
# flow_6_10 = 1.000
# flow_7_10 = 2.000
# flow_8_10 = 4.000
# Source = 7.000

# %%
Inflow_Outflow['incoming_Flow_solution']=Inflow_Outflow['incoming_Flow'].apply(lambda x:x.solution_value)
Inflow_Outflow['outgoing_Flow_solution']=Inflow_Outflow['incoming_Flow'].apply(lambda x:x.solution_value)
Inflow_Outflow
# Out:
#     destination                  incoming_Flow  origin
# 0           0.0                       flow_9_0     0.0  \
# 1           1.0                       flow_9_1     1.0
# 2           2.0                       flow_9_2     2.0
# 3           3.0              flow_0_3+flow_2_3     3.0
# 4           4.0              flow_0_4+flow_1_4     4.0
# 5           5.0              flow_1_5+flow_4_5     5.0
# 6           6.0              flow_3_6+flow_4_6     6.0
# 7           7.0              flow_2_7+flow_3_7     7.0
# 8           8.0              flow_4_8+flow_5_8     8.0
# 9          10.0  flow_6_10+flow_7_10+flow_8_10     NaN
# 10          NaN                         Source     9.0
#
#                  outgoing_flow  incoming_Flow_solution  outgoing_Flow_solution
# 0            flow_0_3+flow_0_4                     6.0                     6.0
# 1            flow_1_4+flow_1_5                     0.0                     0.0
# 2            flow_2_3+flow_2_7                     1.0                     1.0
# 3            flow_3_6+flow_3_7                     2.0                     2.0
# 4   flow_4_6+flow_4_5+flow_4_8                     4.0                     4.0
# 5                     flow_5_8                     3.0                     3.0
# 6                    flow_6_10                     1.0                     1.0
# 7                    flow_7_10                     2.0                     2.0
# 8                    flow_8_10                     4.0                     4.0
# 9                       Source                     7.0                     7.0
# 10  flow_9_0+flow_9_1+flow_9_2                     7.0                     7.0
